# %%
#NAME:N.DHYANA SAI
#REG-NO:20BCE2956
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#2. Load the dataset.
data=pd.read_csv("C:/Users/hp/Downloads/Housing.csv")

# %%
#Perform Below Visualizations.
#Univariate analysis
plt.hist(data['price'])
plt.xlabel('price')
plt.ylabel('Frequency')
plt.title('Distribution of Price')
plt.show()

# %%
categories = list(data['stories'].unique())
value_counts = data['stories'].value_counts()

# %%
plt.pie(value_counts,labels=categories)
# Out:
# ([<matplotlib.patches.Wedge at 0x26e8d1d3070>,
#   <matplotlib.patches.Wedge at 0x26e8d1d3f70>,
#   <matplotlib.patches.Wedge at 0x26e8cfd4430>,
#   <matplotlib.patches.Wedge at 0x26e8cfd48b0>],
#  [Text(0.2173194882526601, 1.078319173540748, '3'),
#   Text(-0.6744482341032301, -0.8689761674033614, '4'),
#   Text(0.8511907813779661, -0.6967598249735469, '2'),
#   Text(1.0723198311988387, -0.24521455833146277, '1')])

# %%
survival_counts = data.groupby('stories')['airconditioning'].value_counts().unstack()
colors = ['tab:blue', 'tab:orange']
survival_counts.plot(kind='bar', stacked=True,color=colors)
plt.xlabel('Number of Stories')
plt.ylabel('Count')
plt.title('Houses Count by Number of stories and Airconditioning')
plt.show()

# %%
sns.boxplot(x='bedrooms', y='price', data=data)
plt.title('Price by Number of bedrooms')
plt.show()

# %%
sns.scatterplot(x='area', y='price', data=data,hue='bedrooms')
plt.title('Price vs. Area')
plt.show()

# %%
sns.catplot(x='parking', hue='mainroad', col='furnishingstatus', data=data, kind='count')
plt.show()

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %%
data['Area_dummy']=data['area']

# %%
z_threshold = 3
z_scores = (data['Area_dummy'] - data['Area_dummy'].mean()) / data['Area_dummy'].std()
outliers = (np.abs(z_scores) > z_threshold)
data.loc[outliers,'Area_dummy'] = data['Area_dummy'].mean()

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking furnishingstatus  Area_dummy
# 0                no             yes        2        furnished      7420.0
# 1                no             yes        3        furnished      8960.0
# 2                no              no        2   semi-furnished      9960.0
# 3                no             yes        3        furnished      7500.0
# 4                no             yes        2        furnished      7420.0
# ..              ...             ...      ...              ...         ...
# 540              no              no        2      unfurnished      3000.0
# 541              no              no        0   semi-furnished      2400.0
# 542              no              no        0      unfurnished      3620.0
# 543              no              no        0        furnished      2910.0
# 544              no              no        0      unfurnished      3850.0
#
# [545 rows x 13 columns]

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
data['furnishingstatus']= label_encoder.fit_transform(data['furnishingstatus'])
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking  furnishingstatus  Area_dummy
# 0                no             yes        2                 0      7420.0
# 1                no             yes        3                 0      8960.0
# 2                no              no        2                 1      9960.0
# 3                no             yes        3                 0      7500.0
# 4                no             yes        2                 0      7420.0
# ..              ...             ...      ...               ...         ...
# 540              no              no        2                 2      3000.0
# 541              no              no        0                 1      2400.0
# 542              no              no        0                 2      3620.0
# 543              no              no        0                 0      2910.0
# 544              no              no        0                 2      3850.0
#
# [545 rows x 13 columns]

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
data['mainroad']= label_encoder.fit_transform(data['mainroad'])
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad guestroom  \
# 0    13300000  7420         4          2        3         1        no
# 1    12250000  8960         4          4        4         1        no
# 2    12250000  9960         3          2        2         1        no
# 3    12215000  7500         4          2        2         1        no
# 4    11410000  7420         4          1        2         1       yes
# ..        ...   ...       ...        ...      ...       ...       ...
# 540   1820000  3000         2          1        1         1        no
# 541   1767150  2400         3          1        1         0        no
# 542   1750000  3620         2          1        1         1        no
# 543   1750000  2910         3          1        1         0        no
# 544   1750000  3850         3          1        2         1        no
#
#     basement hotwaterheating airconditioning  parking  furnishingstatus  \
# 0         no              no             yes        2                 0
# 1         no              no             yes        3                 0
# 2        yes              no              no        2                 1
# 3        yes              no             yes        3                 0
# 4        yes              no             yes        2                 0
# ..       ...             ...             ...      ...               ...
# 540      yes              no              no        2                 2
# 541       no              no              no        0                 1
# 542       no              no              no        0                 2
# 543       no              no              no        0                 0
# 544       no              no              no        0                 2
#
#      Area_dummy
# 0        7420.0
# 1        8960.0
# 2        9960.0
# 3        7500.0
# 4        7420.0
# ..          ...
# 540      3000.0
# 541      2400.0
# 542      3620.0
# 543      2910.0
# 544      3850.0
#
# [545 rows x 13 columns]

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
data['guestroom']= label_encoder.fit_transform(data['guestroom'])
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#     basement hotwaterheating airconditioning  parking  furnishingstatus  \
# 0         no              no             yes        2                 0
# 1         no              no             yes        3                 0
# 2        yes              no              no        2                 1
# 3        yes              no             yes        3                 0
# 4        yes              no             yes        2                 0
# ..       ...             ...             ...      ...               ...
# 540      yes              no              no        2                 2
# 541       no              no              no        0                 1
# 542       no              no              no        0                 2
# 543       no              no              no        0                 0
# 544       no              no              no        0                 2
#
#      Area_dummy
# 0        7420.0
# 1        8960.0
# 2        9960.0
# 3        7500.0
# 4        7420.0
# ..          ...
# 540      3000.0
# 541      2400.0
# 542      3620.0
# 543      2910.0
# 544      3850.0
#
# [545 rows x 13 columns]

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
data['basement']= label_encoder.fit_transform(data['basement'])
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement hotwaterheating airconditioning  parking  furnishingstatus  \
# 0           0              no             yes        2                 0
# 1           0              no             yes        3                 0
# 2           1              no              no        2                 1
# 3           1              no             yes        3                 0
# 4           1              no             yes        2                 0
# ..        ...             ...             ...      ...               ...
# 540         1              no              no        2                 2
# 541         0              no              no        0                 1
# 542         0              no              no        0                 2
# 543         0              no              no        0                 0
# 544         0              no              no        0                 2
#
#      Area_dummy
# 0        7420.0
# 1        8960.0
# 2        9960.0
# 3        7500.0
# 4        7420.0
# ..          ...
# 540      3000.0
# 541      2400.0
# 542      3620.0
# 543      2910.0
# 544      3850.0
#
# [545 rows x 13 columns]

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
data['hotwaterheating']= label_encoder.fit_transform(data['hotwaterheating'])
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating airconditioning  parking  furnishingstatus  \
# 0           0                0             yes        2                 0
# 1           0                0             yes        3                 0
# 2           1                0              no        2                 1
# 3           1                0             yes        3                 0
# 4           1                0             yes        2                 0
# ..        ...              ...             ...      ...               ...
# 540         1                0              no        2                 2
# 541         0                0              no        0                 1
# 542         0                0              no        0                 2
# 543         0                0              no        0                 0
# 544         0                0              no        0                 2
#
#      Area_dummy
# 0        7420.0
# 1        8960.0
# 2        9960.0
# 3        7500.0
# 4        7420.0
# ..          ...
# 540      3000.0
# 541      2400.0
# 542      3620.0
# 543      2910.0
# 544      3850.0
#
# [545 rows x 13 columns]

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
data['airconditioning']= label_encoder.fit_transform(data['airconditioning'])
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  furnishingstatus  \
# 0           0                0                1        2                 0
# 1           0                0                1        3                 0
# 2           1                0                0        2                 1
# 3           1                0                1        3                 0
# 4           1                0                1        2                 0
# ..        ...              ...              ...      ...               ...
# 540         1                0                0        2                 2
# 541         0                0                0        0                 1
# 542         0                0                0        0                 2
# 543         0                0                0        0                 0
# 544         0                0                0        0                 2
#
#      Area_dummy
# 0        7420.0
# 1        8960.0
# 2        9960.0
# 3        7500.0
# 4        7420.0
# ..          ...
# 540      3000.0
# 541      2400.0
# 542      3620.0
# 543      2910.0
# 544      3850.0
#
# [545 rows x 13 columns]

# %%
columns_to_drop = ['price', 'Area_dummy']
x = data.drop(columns_to_drop, axis=1)
y=data['price']

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  furnishingstatus
# 0                  0                1        2                 0
# 1                  0                1        3                 0
# 2                  0                0        2                 1
# 3                  0                1        3                 0
# 4                  0                1        2                 0
# ..               ...              ...      ...               ...
# 540                0                0        2                 2
# 541                0                0        0                 1
# 542                0                0        0                 2
# 543                0                0        0                 0
# 544                0                0        0                 2
#
# [545 rows x 11 columns]

# %%
min_value = data['area'].min()
max_value = data['area'].max()
data['area']  = (data['area'] - min_value) / (max_value - min_value)

# Assign the scaled column back to the dataset
data
# Out:
#         price      area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  0.396564         4          2        3         1          0
# 1    12250000  0.502405         4          4        4         1          0
# 2    12250000  0.571134         3          2        2         1          0
# 3    12215000  0.402062         4          2        2         1          0
# 4    11410000  0.396564         4          1        2         1          1
# ..        ...       ...       ...        ...      ...       ...        ...
# 540   1820000  0.092784         2          1        1         1          0
# 541   1767150  0.051546         3          1        1         0          0
# 542   1750000  0.135395         2          1        1         1          0
# 543   1750000  0.086598         3          1        1         0          0
# 544   1750000  0.151203         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  furnishingstatus  \
# 0           0                0                1        2                 0
# 1           0                0                1        3                 0
# 2           1                0                0        2                 1
# 3           1                0                1        3                 0
# 4           1                0                1        2                 0
# ..        ...              ...              ...      ...               ...
# 540         1                0                0        2                 2
# 541         0                0                0        0                 1
# 542         0                0                0        0                 2
# 543         0                0                0        0                 0
# 544         0                0                0        0                 2
#
#      Area_dummy
# 0        7420.0
# 1        8960.0
# 2        9960.0
# 3        7500.0
# 4        7420.0
# ..          ...
# 540      3000.0
# 541      2400.0
# 542      3620.0
# 543      2910.0
# 544      3850.0
#
# [545 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 46   6000         3          2        4         1          0         0
# 93   7200         3          2        1         1          0         1
# 335  3816         2          1        1         1          0         1
# 412  2610         3          1        2         1          0         1
# 471  3750         3          1        2         1          0         0
# ..    ...       ...        ...      ...       ...        ...       ...
# 71   6000         4          2        4         1          0         0
# 106  5450         4          2        1         1          0         1
# 270  4500         3          2        3         1          0         0
# 435  4040         2          1        1         1          0         0
# 102  5500         3          2        4         1          1         0
#
#      hotwaterheating  airconditioning  parking  furnishingstatus
# 46                 0                1        1                 0
# 93                 0                1        3                 1
# 335                0                1        2                 0
# 412                0                0        0                 2
# 471                0                0        0                 2
# ..               ...              ...      ...               ...
# 71                 0                1        0                 2
# 106                0                1        0                 1
# 270                1                0        1                 0
# 435                0                0        0                 2
# 102                0                1        1                 1
#
# [436 rows x 11 columns]

# %%
y_train
# Out:
# 46     7525000
# 93     6300000
# 335    3920000
# 412    3430000
# 471    3010000
#         ...
# 71     6755000
# 106    6160000
# 270    4340000
# 435    3290000
# 102    6195000
# Name: price, Length: 436, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([5297993.14249125, 6750426.61492706, 3159324.32121344,
#        4694118.82319432, 3455424.38616541, 3719362.82205547,
#        5855623.32076952, 6044830.39884189, 2755895.02258042,
#        2644206.77106942, 9077222.11222358, 2915809.97702118,
#        3159062.29657077, 3420642.75512253, 3916584.69921134,
#        5243762.63334761, 3046326.40939481, 4958973.82490907,
#        4620528.92876186, 3654578.54852775, 5287383.79826482,
#        5521794.39244502, 2843795.96947803, 4381914.34389549,
#        5499031.01072888, 7162767.10789346, 3471551.45640188,
#        5442411.41347199, 7930263.00861181, 3515737.32461717,
#        5989146.93963072, 3441087.43470509, 6903467.15880416,
#        4312032.30634639, 3729953.91562683, 5880036.73104578,
#        5041316.88746565, 4606717.15305102, 3198003.25800653,
#        4719170.74057001, 4712279.6476033 , 3629160.92856762,
#        6730212.15666933, 4147442.99518594, 3844089.09469395,
#        4427860.43120123, 6809826.83756892, 4141476.66481161,
#        3955843.85438125, 3627238.2038619 , 7423609.64568285,
#        2908710.63735614, 4547458.08497466, 4564561.66755856,
#        3932784.39510715, 2697269.72399595, 7038211.83699457,
#        3030252.84989162, 4369924.32239876, 2881950.75943949,
#        4947536.66058872, 3528538.29802227, 5242637.34335284,
#        4454849.40311416, 4235996.72641538, 4681316.12941509,
#        6778038.33837972, 3671484.3928364 , 6137576.48441872,
#        5912067.68118436, 4198828.12471253, 4650069.4944033 ,
#        4706646.94375427, 7674735.54681234, 3619029.42016392,
#        5507517.64739314, 4015589.2535928 , 4145317.77851097,
#        4989963.42515719, 3657882.18336982, 7272444.57017283,
#        4129295.58129251, 6129451.3812604 , 5001293.43916305,
#        2853376.34013651, 7043876.19414646, 2728854.36742684,
#        3741202.26201898, 7540286.14208772, 8232080.78813245,
#        3317857.95731561, 6276962.93201117, 3732334.33500665,
#        3799516.5677852 , 7798429.19500064, 4961329.30770385,
#        5297079.36493966, 6542560.50492383, 4444938.3416259 ,
#        5553064.50253658, 3917043.76958638, 6605052.28652837,
#        3793481.82573211, 6080190.27559598, 5203650.02169873,
#        4444005.82190303, 7138315.63427178, 6513170.6585439 ,
#        6001678.91020546])

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error:', mse)
print('R-squared Score:', r2)
# Out:
# Mean Squared Error: 1852745807729.1365
# R-squared Score: 0.6334513682813151

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %%
ridge_model = Ridge(alpha=0.5)
ridge_model.fit(X_train, y_train)
ridge_pred = ridge_model.predict(X_test)
ridge_mse = mean_squared_error(y_test, ridge_pred)
ridge_r2 = r2_score(y_test, ridge_pred)

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error:', mse)
print('R-squared Score:', r2)
# Out:
# Mean Squared Error: 1852745807729.1365
# R-squared Score: 0.6334513682813151

# %%
lasso_model = Lasso(alpha=0.5)
lasso_model.fit(X_train, y_train)
lasso_pred = lasso_model.predict(X_test)
lasso_mse = mean_squared_error(y_test, lasso_pred)
lasso_r2 = r2_score(y_test, lasso_pred)

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error:', mse)
print('R-squared Score:', r2)
# Out:
# Mean Squared Error: 1852745807729.1365
# R-squared Score: 0.6334513682813151
